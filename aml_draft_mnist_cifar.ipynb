# %% [markdown]
# <a href="https://colab.research.google.com/github/MeilinaR/aml/blob/main/aml_draft_mnist_cifar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/deepmind/learning-to-learn.git
# Out:
# Cloning into 'learning-to-learn'...
# remote: Enumerating objects: 120, done.
# remote: Total 120 (delta 0), reused 0 (delta 0), pack-reused 120
# Receiving objects: 100% (120/120), 90.52 KiB | 1.27 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
# !git clone https://github.com/deepmind/sonnet.git
# Out:
# fatal: destination path 'sonnet' already exists and is not an empty directory.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/
# Out:
# /content

# %%
cd learning-to-learn
# Out:
# [Errno 2] No such file or directory: 'learning-to-learn'
# /content/learning-to-learn

# %%
# !pip uninstall tensorflow
# !pip uninstall dm-sonnet

# !pip install tensorflow==1.5.0
# !pip install dm-sonnet==1.7
# Out:
# Found existing installation: tensorflow 2.7.0
# Uninstalling tensorflow-2.7.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.7.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
#   Successfully uninstalled tensorflow-2.7.0
# WARNING: Skipping dm-sonnet as it is not installed.
# ...

# %%
# !pip install dm-sonnet

# %%
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 489.6 MB 24 kB/s
# ...

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !pip install mock

# %%
# !python train.py --problem=mnist --save_path=./mnist
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:116: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/learning-to-learn/problems.py:155: load_mnist (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# ...

# %%
# !python train.py --problem=cifar --save_path=./cifar
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:116: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/learning-to-learn/problems.py:226: FixedLengthRecordReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
