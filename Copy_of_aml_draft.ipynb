# %% [markdown]
# <a href="https://colab.research.google.com/github/MeilinaR/aml/blob/main/Copy_of_aml_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
# Run the cells below only once

# %%
# The two flags below are used to check whether certain actions have already 
# taken place, as doing them again will result in unwanted behaviour.
has_cloned = False          # Whether the repository has been cloned
has_altered_sonnet = False  # Whether the sonnet package has been changed

# %%
# The following line disables cell output (as it makes the notebook chaotic)
# %%capture capt
assert not has_cloned
# !git clone https://github.com/MeilinaR/aml.git
# !pip install dm-sonnet
# !pip install tensorflow
# !pip install mock

# %tensorflow_version 1.x
has_cloned = True

# %%
cd aml/
# Out:
# /content/aml

# %%
# See https://github.com/deepmind/learning-to-learn/issues/21#issuecomment-358856551
assert not has_altered_sonnet
# !sed '328i\    normalization_build_kwargs["is_training"] = True' /tensorflow-1.15.2/python3.7/sonnet/python/modules/nets/convnet.py > /tensorflow-1.15.2/python3.7/sonnet/python/modules/nets/convnet.py.tmp
! mv /tensorflow-1.15.2/python3.7/sonnet/python/modules/nets/convnet.py.tmp /tensorflow-1.15.2/python3.7/sonnet/python/modules/nets/convnet.py
has_altered_sonnet = True

# %% [markdown]
# # Training
# See the `ReadMe.md` for more details on the specific flags.

# %% [markdown]
# ## Quadratic functions

# %%
# !python train.py --problem=quadratic --save_path=./quadratic --which_aml=fixed --fixed_lambda=0.00001 --num_epochs=10000
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:138: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# LAMBDA set to 1e-05
# WARNING:tensorflow:From /content/aml/meta.py:82: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
# !python train.py --problem=quadratic --save_path=./quadratic --which_aml=fixed --fixed_lambda=0.0001 --num_epochs=10000
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:138: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# LAMBDA set to 0.0001
# Folder ./quadratic already exists
# WARNING:tensorflow:From /content/aml/meta.py:82: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
# !python train.py --problem=quadratic --save_path=./quadratic --which_aml=fixed --fixed_lambda=0.001 --num_epochs=10000
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:138: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# LAMBDA set to 0.001
# Folder ./quadratic already exists
# WARNING:tensorflow:From /content/aml/meta.py:82: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
# !python train.py --problem=quadratic --save_path=./quadratic --which_aml=fixed --fixed_lambda=0.01 --num_epochs=10000
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:138: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# LAMBDA set to 0.01
# Folder ./quadratic already exists
# WARNING:tensorflow:From /content/aml/meta.py:82: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
# !python train.py --problem=quadratic --save_path=./quadratic --which_aml=fixed --fixed_lambda=0.1 --num_epochs=10000
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:138: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# LAMBDA set to 0.1
# Folder ./quadratic already exists
# WARNING:tensorflow:From /content/aml/meta.py:82: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %% [markdown]
# ## MNIST

# %%
# 0.00001 is being trained in a different notebook on mreksoprodjo@gmail.com
# !python train.py --problem=mnist --save_path=./mnist --which_aml=fixed --fixed_lambda=0.0001 --num_epochs=10000
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:138: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# LAMBDA set to 0.0001
# WARNING:tensorflow:From /content/aml/problems.py:156: load_mnist (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# 0.00001 is being trained in a different notebook on mreksoprodjo@gmail.com
# !python train.py --problem=mnist --save_path=./mnist --which_aml=fixed --fixed_lambda=0.0001 --num_epochs=10000
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From train.py:138: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# LAMBDA set to 0.0001
# WARNING:tensorflow:From /content/aml/problems.py:156: load_mnist (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# Being ran on mreksoprodjo@gmail.com
# !python train.py --problem=mnist --save_path=./mnist --which_aml=fixed --fixed_lambda=0.01 --num_epochs=10000

# %%
# Run on backup email #2
# !python train.py --problem=mnist --save_path=./mnist --which_aml=fixed --fixed_lambda=0.1 --num_epochs=10000

# %% [markdown]
# # Evaluation
# For saved optimizers, use `--path=./saved_optimizers/{PROBLEM}`. For optimizers that you just created using the Training cells above, use `--path=./{PROBLEM}`

# %% [markdown]
# ### Quadratic functions

# %%
# !python evaluate.py --problem=quadratic --optimizer=Adam --path=./saved_optimizers/quadratic
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From evaluate.py:117: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/aml/problems.py:79: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %%
# !python evaluate.py --problem=quadratic --optimizer=L2L --path=./saved_optimizers/quadratic/
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/sonnet/python/modules/util.py:63: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From evaluate.py:117: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From /content/aml/meta.py:82: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# ...

# %% [markdown]
# ### MNIST

# %%
# !python evaluate.py --problem=mnist --optimizer=L2L --path=./saved_optimizers/mnist

# %%
# !python evaluate.py --problem=mnist --optimizer=Adam

# %% [markdown]
# # Plotting

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_history(filename: str):
    data = np.loadtxt(f"saved_histories/{filename}", delimiter=',', skiprows=1)
    means = np.mean(data, axis=0)
    stds = np.std(data, axis=0)
    return means, stds

def make_history_plot(label_to_filename: dict, title: str):
    fig = plt.figure(figsize=[5,3])
    for label, filename in label_to_filename.items():
        means, stds = load_history(filename)
        plt.plot(means, label=label)
        fill_between(means, stds)

    plt.title(title, fontsize=18)
    plt.xlabel("Step", fontsize=16), plt.ylabel("Cost", fontsize=16)
    plt.legend(), plt.yscale('log')
    plt.show()

fill_between = lambda m, s: plt.fill_between(range(len(m)), y1=m-s, y2=m+s, alpha=0.5)

# %%
quadratics = {
    'L2L': 'quadratic_L2L.csv',
    'Adam': 'quadratic_Adam.csv',
    #'λ = 0.1': 'quadratic_L2L_0.1.csv',
    'λ = 0.01': 'quadratic_L2L_0.01.csv',
    'λ = 0.001': 'quadratic_L2L_0.001.csv',
    'λ = 0.0001': 'quadratic_L2L_0.0001.csv',
    'λ = 0.00001': 'quadratic_L2L_0.0001.csv',
}
make_history_plot(quadratics, "Quadratics optimizer performance")

# %%
mnist = {
    'L2L': 'mnist_L2L.csv',
    'Adam': 'mnist_Adam.csv',
    'λ = 0.1': 'mnist_fixed_0.1.csv',
    'λ = 0.01': 'mnist_fixed_0.01.csv',
    'λ = 0.001': 'mnist_fixed_0.001.csv',
    'λ = 0.0001': 'mnist_fixed_0.0001.csv',
    'λ = 0.0001': 'mnist_fixed_0.0001.csv',
}
make_history_plot(mnist, "MNIST optimizer performance")

# %% [markdown]
# # Git commands

# %%
# !git reset --hard HEAD
# Out:
# HEAD is now at ad2ec30 Old notebook cleanup that we did not use anymore

# %%
# !git add .

# %%
# !git commit -m "All the quadratic experiments with a varying lambda value, including .csv files and .l2l files."
# Out:
# [main 89daecc] All the quadratic experiments with a varying lambda value, including .csv files and .l2l files.
#  13 files changed, 622 insertions(+)
#  create mode 100644 saved_histories/quadratic_Adam.csv
#  create mode 100644 saved_histories/quadratic_L2L.csv
#  create mode 100644 saved_histories/quadratic_L2L_0.00001.csv
#  create mode 100644 saved_histories/quadratic_L2L_0.0001.csv
#  create mode 100644 saved_histories/quadratic_L2L_0.001.csv
#  create mode 100644 saved_histories/quadratic_L2L_0.01.csv
#  create mode 100644 saved_histories/quadratic_L2L_0.1.csv
#  create mode 100644 saved_optimizers/mnist/cw_default.l2l
#  create mode 100644 saved_optimizers/quadratic/cwfixed0.00001.l2l
#  create mode 100644 saved_optimizers/quadratic/cwfixed0.0001.l2l
#  create mode 100644 saved_optimizers/quadratic/cwfixed0.001.l2l
#  create mode 100644 saved_optimizers/quadratic/cwfixed0.01.l2l
#  create mode 100644 saved_optimizers/quadratic/cwfixed0.1.l2l

# %%
# !git config --global user.email "meilinareksoprodjo12@gmail.com"
# !git config --global user.name "MeilinaR"

# %%
# !git push
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git pull

# %%
# !git status377
